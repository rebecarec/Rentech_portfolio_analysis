# %% [markdown]
# <a href="https://colab.research.google.com/github/rebecarec/Rentech_portfolio_analysis/blob/main/Team_2_Top10_per_industry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import warnings
import yfinance as yf
from google.colab import files

warnings.filterwarnings('ignore') ### to kill the initial unecesary warnings

### Defining the tickersss
tickers = ['PLTR', 'AAPL', 'MU', 'NVDA', 'VRSN', 'INTC', 'WDC', 'AVGO', 'MSFT',
           'NFLX', 'UTHR', 'UNH', 'EXEL', 'NVS', 'ABBV', 'LLY', 'JNJ', 'MRK',
           'AMGN', 'PFE', 'XOM', 'CVX', 'COP', 'EOG', 'OXY', 'SHEL', 'BP', 'NEE',
           'BTU', 'SLB', 'SCHW', 'JPM', 'BAC', 'GS', 'MS', 'BRK.B', 'C', 'MA',
           'V', 'BLK', 'CVNA', 'COST', 'AMZN', 'NKE', 'HD', 'WMT', 'PG', 'KO',
           'PEP', 'SBUX', 'KGC', 'FNV', 'FCX', 'CAT', 'DE', 'HON', 'GE', 'MMM', 'NEM']

### Downloading the tickers period
RT_current = yf.download( tickers=tickers,
                                start="2025-06-15",
                                end="2026-06-15",  # 12 months period analysis
                                interval="1d")

##########################################################################

# Create a dictionary to store metadata for each ticker
ticker_metadata = []

for ticker in tickers:
    try:
        RT_current_info = yf.Ticker(ticker).info
        # Extract desired fields with fallbacks in case data is missing
        sector = RT_current_info.get('sector', 'N/A')
        industry = RT_current_info.get('industry', 'N/A')

        ticker_metadata.append({
            'ticker': ticker,
            'sector': sector,
            'industry': industry
        })
    except Exception as e:
        print(f"Could not fetch data for {ticker}: {e}")
        ticker_metadata.append({'ticker': ticker, 'sector': 'N/A', 'industry': 'N/A'})

# Convert metadata list into a DataFrame
metadata_df = pd.DataFrame(ticker_metadata)

############################################### CREATING THE TABLE

print("--- RENTEC HISTORICAL CLOSE PRICES (REFORMATTED) ---")

##### Defining values for the new format
RT_current_close_prices = RT_current['Close']
RT_current_close_prices = RT_current_close_prices.reset_index()

RT_current_formatted_df = RT_current_close_prices.melt( id_vars=['Date'],
                                                        var_name='ticker',
                                                        value_name='close_value')    # The prices of the stocks per day
RT_current_formatted_df['ID'] = RT_current_formatted_df['Date'].astype(str) + "_" + RT_current_formatted_df['ticker']
RT_current_formatted_df = pd.merge(RT_current_formatted_df, metadata_df, on='ticker', how='left')

##### rearranging columns
RT_current_formatted_df = RT_current_formatted_df[['ID', 'ticker', 'Date', 'close_value','sector','industry']]

##### Print the final result
print(RT_current_formatted_df)

########################################## DONWLOAD WINDOW TO THE EXTRACTED FILE
filename = 'RT_possible10.csv'

#Save the file temporarily onto the Colab cloud server
RT_current_formatted_df.to_csv(filename, index=False)
#Trigger the browser to download it to your local machine
files.download(filename)
# Out:
# [*********************100%***********************]  59 of 59 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK.B']: YFTzMissingError('possibly delisted; no timezone found')
# --- RENTEC HISTORICAL CLOSE PRICES (REFORMATTED) ---
#                     ID ticker       Date  close_value      sector  \
# 0      2025-06-16_AAPL   AAPL 2025-06-16   197.635941  Technology
# 1      2025-06-17_AAPL   AAPL 2025-06-17   194.866913  Technology
# 2      2025-06-18_AAPL   AAPL 2025-06-18   195.803223  Technology
# 3      2025-06-20_AAPL   AAPL 2025-06-20   200.205750  Technology
# 4      2025-06-23_AAPL   AAPL 2025-06-23   200.703766  Technology
# ...                ...    ...        ...          ...         ...
# 14745   2026-06-08_XOM    XOM 2026-06-08   151.750000      Energy
# 14746   2026-06-09_XOM    XOM 2026-06-09   148.910004      Energy
# 14747   2026-06-10_XOM    XOM 2026-06-10   150.619995      Energy
# 14748   2026-06-11_XOM    XOM 2026-06-11   146.600006      Energy
# 14749   2026-06-12_XOM    XOM 2026-06-12   147.009995      Energy
#
#                    industry
# 0      Consumer Electronics
# 1      Consumer Electronics
# 2      Consumer Electronics
# 3      Consumer Electronics
# 4      Consumer Electronics
# ...                     ...
# 14745  Oil & Gas Integrated
# 14746  Oil & Gas Integrated
# 14747  Oil & Gas Integrated
# 14748  Oil & Gas Integrated
# 14749  Oil & Gas Integrated
#
# [14750 rows x 6 columns]
